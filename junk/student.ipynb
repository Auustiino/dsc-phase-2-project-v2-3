# %% [markdown]
# ## A.B. Consulting
#
# * Student name: Austin B.
# * Student pace: full time
# * Scheduled project review date/time: 4/1/22
# * Instructor name: Veen!

# %% [markdown]
# # Goal - Target - data overview and what was used
#
#     - Estimate budget for first time home buyers given desired         criteria
#     - Home buyers have preferred criteria
#         - King County, Washington
#         - No less than than 2 bedrooms
#         - No less than 2000 SQFT
#         - Built after 2000
#         - Above Average Grade

# %% [markdown]
# # King County Data Set
# ## Initial exploration, Finding Correlations

# %% [markdown]
# ## Price and Bedrooms
# ### Correlation towards higher price
#
#
# ![Screen%20Shot%202022-04-01%20at%201.56.46%20PM.png](attachment:Screen%20Shot%202022-04-01%20at%201.56.46%20PM.png)

# %% [markdown]
# ## Price and Square Feet of Living Space
# ### Highly Positive Correlation towards higher price
#
#
# ![Screen%20Shot%202022-04-01%20at%201.58.04%20PM.png](attachment:Screen%20Shot%202022-04-01%20at%201.58.04%20PM.png)

# %% [markdown]
# ## Price and Year Built
#
# ![Screen%20Shot%202022-04-01%20at%201.59.43%20PM.png](attachment:Screen%20Shot%202022-04-01%20at%201.59.43%20PM.png)

# %% [markdown]
# # Price and Grade
# ### Positive Correlation towards higher price
#
# ![Screen%20Shot%202022-04-01%20at%202.18.01%20PM.png](attachment:Screen%20Shot%202022-04-01%20at%202.18.01%20PM.png)

# %% [markdown]
# # Optimal Price Prediction
# ### Was able to pool criteria found to be relevant in predicting price
#     - Primary Figures for Price Prediction including all data
#         - Square feet Living Area
#         - Zipcode
#         - Year Built
#         - Grade
# This model accounts for 83.4% of price variation is explained by our feature varibles

# %% [markdown]
# ![Screen%20Shot%202022-04-01%20at%203.12.57%20AM.png](attachment:Screen%20Shot%202022-04-01%20at%203.12.57%20AM.png)

# %% [markdown]
# # Target Price Prediction
# ### Was able to pool criteria found to be relevant in predicting Target Price
#     - Criteria of Figures for Target Price Prediction
#         - Square feet Living Area
#         - Bedrooms
#         - Year Built
#         - Grade
# This model accounts for 89.3% of price variation is explained by our feature varibles

# %% [markdown]
# ![Screen%20Shot%202022-04-01%20at%203.29.02%20PM.png](attachment:Screen%20Shot%202022-04-01%20at%203.29.02%20PM.png)

# %% [markdown]
# ## Price Prediction meeting all Criteria
# ### $ 696,830.033
